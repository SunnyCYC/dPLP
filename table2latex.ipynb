# %%
import os
import mir_eval
import mir_eval.util as util
import glob
from pathlib import Path
import numpy as np
import pandas as pd
import csv
import tqdm

def getAudioPaths(audio_txt):
    audiopaths = []
    with open(audio_txt, 'r') as file:
        for line in file.readlines():
            audiopaths.append(line.strip('\n'))

    return audiopaths

def getTBSnames(row):
    track_name = os.path.basename(row['trackname'])
    
    return os.path.basename(track_name)

# %%
date = '2025-04-04_MergedResults-dplp'
# pth_type = 'raw'
pth_type = 'final'
main_dir = r'C:\Users\sunnycyc\OneDrive\桌面\github_dPLP_final\evaluation\2025-06-12_eval-dPLP\csvfiles'

csv_savedir = os.path.join(main_dir, date)
csv_rpaths = glob.glob(os.path.join(main_dir, '2025-06-12-{}-*.csv'.format(pth_type)))

# csv_rpaths = glob.glob(os.path.join(main_dir, '2025-03*'))

if not os.path.exists(csv_savedir):
    Path(csv_savedir).mkdir(parents = True, exist_ok = True)


df_list = []
for csv_rpath in csv_rpaths:
    
    ### organize results 
    df_list.append( pd.read_csv(csv_rpath))
    
df = pd.concat(df_list)
datasets = list(df['Dataset'].unique())
print(len(df))

# print(df.keys())
df = df[['Dataset', 'model_type', 'head_type', 'trackname',
       'Track', 'F1', 'R', 'P', 'F-L2-onbeat', 'P-L2-onbeat', 'R-L2-onbeat',
       'F-L2-half', 'P-L2-half', 'R-L2-half', 'F-L2-third', 'P-L2-third',
       'R-L2-third', 'F-L2-any', 'P-L2-any', 'R-L2-any']]

model_types = sorted(df['model_type'].unique().tolist())
datasets = sorted(df['Dataset'].unique().tolist())
head_types = sorted(df['head_type'].unique().tolist())

print('datasets:', datasets)
print('model_types:', model_types)
print('head_type:', head_types)
df['tbsname'] = df.apply(getTBSnames, axis = 1)
trackbsnames = sorted(df['tbsname'].unique().tolist())
# Out:
# 1300
# datasets: ['gtzan']
# model_types: ['M1', 'M2', 'M3', 'SFX']
# head_type: ['dplp-N10', 'dplp-N3', 'dplp-N5', 'fused', 'spectral_flux']

# %%
train_info_dir = './dataset/gtzan/train-info/'
test_txt = os.path.join(train_info_dir, "test_files.txt")
test_tracks = getAudioPaths(test_txt)
test_tbs = [os.path.basename(i).replace('.wav', '.beats') for i in test_tracks]

df2 = df.loc[df['tbsname'].isin(test_tbs)]
print(len(df2))
#%%
dataset = 'gtzan'
model_type = ['M1', 'M2', 'M3', 'SFX'][3]

# model_type_dict = {i:i for i in ['M1', 'M2', 'M3', 'SFX']}
model_type_dict = {'M1': 'M1', 'M2': 'M2', 'M3': 'M3', 'SFX': 'SFX'}

head_rname_dict = {
    'dplp-N10':'dPLP-N10', 
    'dplp-N3':'dPLP-N3', 
    'dplp-N5':'dPLP-N5', 
    'fused':'F', 
    'spectral_flux':'S', 
    }


avg_list = []
std_list = []
def getAudioPaths(audio_txt):
    audiopaths = []
    with open(audio_txt, 'r') as file:
        for line in file.readlines():
            audiopaths.append(line.strip('\n'))
    return audiopaths

# unseen_list = []
train_info_dir = './dataset/gtzan/train-info/'
test_txt = os.path.join(train_info_dir, "test_files.txt")
test_tracks = getAudioPaths(test_txt)
test_tbs = [os.path.basename(i).replace('.wav', '.beats') for i in test_tracks]

df = df.loc[df['tbsname'].isin(test_tbs)]
# print(len(df))
for head_type in [ 'spectral_flux', 'dplp-N3','dplp-N5', 'dplp-N10', 'fused']:
# for head_type in [ 'rnn',  'fused']:
# for head_type in [ 'rnn']:
# for head_type in [ 'spectral_flux', 'fused']:
# for head_type in [ 'spectral_flux']:
    # break
    avg_list = []
    std_list = []
    # for fold_num in np.arange(0, 1):
        # break
        
    
        
    ### get df for corresponding models and trackname
    select_df = df2.loc[
        (df2['trackname'].isin(test_tbs))
                        # &(df['dplprnn_info']==dplprnn_type)
                        # &(df['fold']=='F'+str(fold_num))
                        # &(df['train-type']==train_type)
                        # &(df['theta']==theta)
                        &(df2['model_type']==model_type)
                        &(df2['head_type']==head_type)
                        &(df2['Dataset']==dataset)
                        # &(df['target-smth']==gsmn)
                        # &(df['Acti']==Acti )
                     ]
    # print(len(select_df))
    avg_list.append([select_df["F1"].mean(), select_df["P"].mean(), select_df["R"].mean(), 
                         select_df["F-L2-onbeat"].mean(), 
                         # select_df["F-L4-onbeat"].mean(), 
                         # select_df["F-L8-onbeat"].mean(), 
                         select_df["P-L2-onbeat"].mean(), 
                         # select_df["P-L4-onbeat"].mean(), 
                         # select_df["P-L8-onbeat"].mean(), 
                         select_df["R-L2-onbeat"].mean(), 
                         # select_df["R-L4-onbeat"].mean(), 
                         # select_df["R-L8-onbeat"].mean()
                         ]
                    
                    )
    std_list.append([select_df["F1"].std(), select_df["P"].std(), select_df["R"].std(), 
                     select_df["F-L2-onbeat"].std(), 
                     # select_df["F-L4-onbeat"].std(), 
                     # select_df["F-L8-onbeat"].std(), 
                     select_df["P-L2-onbeat"].std(), 
                     # select_df["P-L4-onbeat"].std(), 
                     # select_df["P-L8-onbeat"].std(), 
                     select_df["R-L2-onbeat"].std(), 
                     # select_df["R-L4-onbeat"].std(), 
                     # select_df["R-L8-onbeat"].std()
                     ]
                    
                    )
    avg_np = np.array(avg_list)
    avg_res = avg_np.mean(axis =0)
    std_np = np.array(std_list)
    std_res = std_np.mean(axis = 0)
       
    print( '{}-{}'.format( model_type, head_rname_dict[head_type]) + \
          '& {:.3f} '.format(avg_res[0]) + \
            '& {:.3f} '.format(avg_res[1]) + \
            '& {:.3f} '.format(avg_res[2]) + \
            '& {:.3f} '.format(avg_res[3]) + \
            '& {:.3f} '.format(avg_res[4]) + \
            # '& {:.3f} '.format(avg_res[5]) + \
            # '& {:.3f} '.format(avg_res[6]) + \
            # '& {:.3f} '.format(avg_res[7]) + \
            # '& {:.3f} '.format(avg_res[8]) + \
            # '& {:.3f} '.format(avg_res[9]) + \
            # '& {:.3f} '.format(avg_res[10]) + \
            '& {:.3f}\\\\'.format(avg_res[5]) 
    
          )
# Out:
# 260
# SFX-S& 0.580 & 0.441 & 0.887 & 0.160 & 0.129 & 0.219\\
# SFX-dPLP-N3& nan & nan & nan & nan & nan & nan\\
# SFX-dPLP-N5& nan & nan & nan & nan & nan & nan\\
# SFX-dPLP-N10& nan & nan & nan & nan & nan & nan\\
# SFX-F& nan & nan & nan & nan & nan & nan\\
